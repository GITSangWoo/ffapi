# %%
import pandas as pd

# %%
df = pd.read_parquet('/home/centa/code/ffapi/data')
df
# Out:
#       movieCd multiMovieYn repNationCd
# 0    20100513            Y           K
# 1    20151381            Y           F
# 2    20158951            Y           K
# 3    20145504            N           K
# 4    20143726            Y           K
# ..        ...          ...         ...
# 793  19860125            Y        None
# 794  20151321         None           K
# 795  20154861         None           K
# 796  19698128         None           K
# 797  20152641         None           K
#
# [798 rows x 3 columns]
